# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE

# 读取数据集
data = pd.read_excel("2b数据处理结果.xlsx")

# 提取特征列
X = data.iloc[:, 1:]  # 假设特征列从第二列开始，如果不是，请调整索引

# 使用t-SNE进行降维
tsne = TSNE(n_components=3, random_state=42)
X_tsne = tsne.fit_transform(X)

# 创建一个三维散点图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 在三维空间中绘制散点图
ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2])

# 设置坐标轴标签
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')

# 标题
ax.set_title('t-SNE')

# 显示图形
plt.show()

# 将图形保存为PDF
fig.savefig("tsne_3d_plot.pdf")
# Out:
# /root/miniconda3/envs/jupyter-env/lib/python3.11/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /root/miniconda3/envs/jupyter-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32500 (\N{CJK UNIFIED IDEOGRAPH-7EF4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/jupyter-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/jupyter-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38477 (\N{CJK UNIFIED IDEOGRAPH-964D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/jupyter-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/envs/jupyter-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_36328/3398092938.py:35: UserWarning: Glyph 32500 (\N{CJK UNIFIED IDEOGRAPH-7EF4}) missing from current font.
#   fig.savefig("tsne_3d_plot.pdf")
# /tmp/ipykernel_36328/3398092938.py:35: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   fig.savefig("tsne_3d_plot.pdf")
# /tmp/ipykernel_36328/3398092938.py:35: UserWarning: Glyph 38477 (\N{CJK UNIFIED IDEOGRAPH-964D}) missing from current font.
#   fig.savefig("tsne_3d_plot.pdf")
# /tmp/ipykernel_36328/3398092938.py:35: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from current font.
#   fig.savefig("tsne_3d_plot.pdf")
# /tmp/ipykernel_36328/3398092938.py:35: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from current font.
#   fig.savefig("tsne_3d_plot.pdf")
